# %%
import pandas as pd
from ntscraper import Nitter
import time

# Lista de instancias de Nitter
scraper = Nitter()

def get_tweets(username, number=50):
    try:
        tweets = scraper.get_tweets(username, mode="user", number=number)
        return tweets
    except Exception as e:
        print(f"Error fetching tweets for {username}: {e}")
        return {}

# Lista de usuario"

usuarios = ['eldelaconsty', 'camion_desde'
   ]
"""'Cicmty', 'conagua_mx' , 'elnortelocal', 'LoQuePasaenNL', 'eldelaconsty', 'camion_desde',
    'metrorreynlofi1', 'MovilidadSN', 'SSP_Apodaca', 'PC_NuevoLeon', 'TodosSomosHLM',
    'AtentosMTYSur', 'Apodaca_News', 'ArbSanJorge', 'SoyDeSanNicolas', 'abimaelsal',
    'BomberosNL', 'nelvaldez', 'MAGS_SP', 'saz2000', 'DarkKnightMty', 'revistacodigo21',
    'Mty_Leones', 'cesarmty', '911SanPedro', 'SSPCMonterrey', 'pc_mty', 'rayelizalder',
    'Informativo3651', 'arualsanpedrogg', 'JulioCesarCano', 'nmasmonterrey', 'info7mty',
    'ABCNoticiasMX', 'AsiEsMonterrey', 'GobSanNicolas', 'PortalElPunto',
    'gob_Escobed', 'mtygob', 'joluisgarcia', 'visionmty1', 'QuePasaEnS', 'LCAlatorre',
    'IdentidadNL', 'MtyFollow', 'ayd_monterrey', 'ComunidadMTY', 'municipiodegpe',
    'CiudaDanaMtySur'
]"""

# Recopilar tweets para cada usuario
all_tweets = []

for usuario in usuarios:
    for _ in range(3):  # Intentar obtener tweets hasta 3 veces si es necesario
        tweets_data = get_tweets(usuario, number=50)  # Obtener hasta 5 tweets por usuario
        if 'tweets' in tweets_data and len(tweets_data['tweets']) > 0:
            for tweet_info in tweets_data['tweets']:
                tweet_link = tweet_info['link']
                tweet_text = tweet_info['text']
                user_name = tweet_info['user']['name']
                user_username = tweet_info['user']['username']
                tweet_date = tweet_info['date']
                comments = tweet_info['stats']['comments']
                retweets = tweet_info['stats']['retweets']
                quotes = tweet_info['stats']['quotes']
                likes = tweet_info['stats']['likes']

                # Crear un diccionario con la información del tweet
                tweet_details = {
                    'Usuario': user_username,
                    'Nombre': user_name,
                    'Fecha': tweet_date,
                    'Texto': tweet_text,
                    'Likes': likes,
                    'Retweets': retweets,
                    'Comentarios': comments,
                    'Citas': quotes,
                    'Enlace': tweet_link
                }

                # Añadir multimedia si está disponible
                if 'pictures' in tweet_info and tweet_info['pictures']:
                    tweet_details['Imágenes'] = tweet_info['pictures']
                if 'videos' in tweet_info and tweet_info['videos']:
                    tweet_details['Videos'] = tweet_info['videos']
                if 'gifs' in tweet_info and tweet_info['gifs']:
                    tweet_details['GIFs'] = tweet_info['gifs']

                # Añadir el tweet procesado a la lista de todos los tweets
                all_tweets.append(tweet_details)
            break  # Salir del bucle de reintentos si se obtienen tweets
        else:
            print(f"No se encontraron tweets para el usuario {usuario} en el intento {_ + 1}")
        time.sleep(1)  # Esperar un segundo antes de intentar de nuevo

# Convertir la lista de diccionarios en un DataFrame de pandas
df = pd.DataFrame(all_tweets)

# Guardar el DataFrame en un archivo CSV
df.to_csv('tweets_Jun22-4.csv', index=False)
# Out:
# Testing instances:  92%|███████████████████████████████████████████████████████████████████████      | 71/77 [01:14<00:02,  2.56it/s]
# 23-Jun-24 12:50:53 - Certificate did not match expected hostname: nt.ggtyler.dev. Certificate: {'subject': ((('commonName', '4g.ggtyler.dev'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '03A4459CE6DA31CFF555DB78FF3F35BFEA88', 'notBefore': 'May 14 10:55:44 2024 GMT', 'notAfter': 'Aug 12 10:55:43 2024 GMT', 'subjectAltName': (('DNS', '4g.ggtyler.dev'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# Testing instances:  94%|████████████████████████████████████████████████████████████████████████     | 72/77 [01:14<00:01,  2.82it/s]
# 23-Jun-24 12:50:54 - Certificate did not match expected hostname: nitter.uni-sonia.com. Certificate: {'subject': ((('commonName', '*.xserver.jp'),),), 'issuer': ((('countryName', 'JP'),), (('organizationName', 'CloudSecure Corporation'),), (('commonName', 'CloudSecure RSA Domain Validation Secure Server CA 2'),)), 'version': 3, 'serialNumber': 'ACA67AD2030638EE2DCE8E845B8299A6', 'notBefore': 'Mar 11 00:00:00 2024 GMT', 'notAfter': 'Apr 11 23:59:59 2025 GMT', 'subjectAltName': (('DNS', '*.xserver.jp'), ('DNS', 'xserver.jp')), 'OCSP': ('http://ocsp.sectigo.com',), 'caIssuers': ('http://crt.sectigo.com/CloudSecureRSADomainValidationSecureServerCA2.crt',)}
# Testing instances:  99%|████████████████████████████████████████████████████████████████████████████ | 76/77 [01:17<00:00,  1.60it/s]
# 23-Jun-24 12:50:56 - Certificate did not match expected hostname: nitter.tinfoil-hat.net. Certificate: {'subject': ((('commonName', 'jelly.tinfoil-hat.de'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '044FDE3E7089FB997C3D8AFDE2412CE51554', 'notBefore': 'May 15 09:29:23 2024 GMT', 'notAfter': 'Aug 13 09:29:22 2024 GMT', 'subjectAltName': (('DNS', 'jelly.tinfoil-hat.de'),), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# Testing instances: 100%|█████████████████████████████████████████████████████████████████████████████| 77/77 [01:17<00:00,  1.01s/it]
# 23-Jun-24 12:50:56 - No instance specified, using random instance https://nitter.privacydev.net
# 23-Jun-24 12:50:57 - Empty page on https://nitter.privacydev.net
# No se encontraron tweets para el usuario eldelaconsty en el intento 1
# 23-Jun-24 12:51:00 - No instance specified, using random instance https://nitter.privacydev.net
# 23-Jun-24 12:51:01 - Empty page on https://nitter.privacydev.net
# No se encontraron tweets para el usuario eldelaconsty en el intento 2
# 23-Jun-24 12:51:04 - No instance specified, using random instance https://nitter.privacydev.net
# 23-Jun-24 12:51:04 - Empty page on https://nitter.privacydev.net
# No se encontraron tweets para el usuario eldelaconsty en el intento 3
# 23-Jun-24 12:51:07 - No instance specified, using random instance https://nitter.privacydev.net
# 23-Jun-24 12:51:08 - Empty page on https://nitter.privacydev.net
# No se encontraron tweets para el usuario camion_desde en el intento 1
# 23-Jun-24 12:51:11 - No instance specified, using random instance https://nitter.privacydev.net
# 23-Jun-24 12:51:11 - Empty page on https://nitter.privacydev.net
# No se encontraron tweets para el usuario camion_desde en el intento 2
# 23-Jun-24 12:51:14 - No instance specified, using random instance https://nitter.privacydev.net
# 23-Jun-24 12:51:15 - Empty page on https://nitter.privacydev.net
# No se encontraron tweets para el usuario camion_desde en el intento 3

# %%
df
# Out:
#     Usuario Nombre                        Fecha  \
# 0   @Cicmty    CIC  Jun 23, 2024 · 12:10 AM UTC
# 1   @Cicmty    CIC  Jun 23, 2024 · 12:02 AM UTC
# 2   @Cicmty    CIC  Jun 22, 2024 · 11:27 PM UTC
# 3   @Cicmty    CIC  Jun 22, 2024 · 11:20 PM UTC
# 4   @Cicmty    CIC  Jun 22, 2024 · 11:15 PM UTC
# 5   @Cicmty    CIC  Jun 22, 2024 · 11:00 PM UTC
# 6   @Cicmty    CIC  Jun 22, 2024 · 10:54 PM UTC
# 7   @Cicmty    CIC  Jun 22, 2024 · 10:51 PM UTC
# 8   @Cicmty    CIC  Jun 22, 2024 · 10:47 PM UTC
# 9   @Cicmty    CIC  Jun 22, 2024 · 10:45 PM UTC
# 10  @Cicmty    CIC  Jun 22, 2024 · 10:28 PM UTC
# 11  @Cicmty    CIC  Jun 22, 2024 · 10:14 PM UTC
# 12  @Cicmty    CIC   Jun 22, 2024 · 9:48 PM UTC
# 13  @Cicmty    CIC   Jun 22, 2024 · 9:45 PM UTC
# 14  @Cicmty    CIC   Jun 22, 2024 · 9:43 PM UTC
# 15  @Cicmty    CIC   Jun 22, 2024 · 9:05 PM UTC
# 16  @Cicmty    CIC   Jun 22, 2024 · 9:03 PM UTC
# 17  @Cicmty    CIC   Jun 22, 2024 · 8:56 PM UTC
# 18  @Cicmty    CIC   Jun 22, 2024 · 8:41 PM UTC
# 19  @Cicmty    CIC   Jun 22, 2024 · 8:24 PM UTC
# 20  @Cicmty    CIC   Jun 22, 2024 · 8:15 PM UTC
# 21  @Cicmty    CIC   Jun 22, 2024 · 8:13 PM UTC
# 22  @Cicmty    CIC   Jun 22, 2024 · 8:06 PM UTC
# 23  @Cicmty    CIC   Jun 22, 2024 · 7:39 PM UTC
# 24  @Cicmty    CIC   Jun 22, 2024 · 7:30 PM UTC
# 25  @Cicmty    CIC   Jun 22, 2024 · 7:23 PM UTC
# 26  @Cicmty    CIC   Jun 22, 2024 · 7:19 PM UTC
# 27  @Cicmty    CIC   Jun 22, 2024 · 7:11 PM UTC
# 28  @Cicmty    CIC   Jun 22, 2024 · 7:02 PM UTC
# 29  @Cicmty    CIC   Jun 22, 2024 · 6:58 PM UTC
# 30  @Cicmty    CIC   Jun 22, 2024 · 6:27 PM UTC
# 31  @Cicmty    CIC   Jun 22, 2024 · 6:25 PM UTC
# 32  @Cicmty    CIC   Jun 22, 2024 · 6:18 PM UTC
# 33  @Cicmty    CIC   Jun 22, 2024 · 6:00 PM UTC
# 34  @Cicmty    CIC   Jun 22, 2024 · 5:57 PM UTC
# 35  @Cicmty    CIC   Jun 22, 2024 · 5:27 PM UTC
# 36  @Cicmty    CIC   Jun 22, 2024 · 5:18 PM UTC
# 37  @Cicmty    CIC   Jun 22, 2024 · 5:16 PM UTC
# 38  @Cicmty    CIC   Jun 22, 2024 · 5:08 PM UTC
# 39  @Cicmty    CIC   Jun 22, 2024 · 5:06 PM UTC
# 40  @Cicmty    CIC   Jun 22, 2024 · 5:00 PM UTC
# 41  @Cicmty    CIC   Jun 22, 2024 · 4:51 PM UTC
# 42  @Cicmty    CIC   Jun 22, 2024 · 4:47 PM UTC
# 43  @Cicmty    CIC   Jun 22, 2024 · 4:41 PM UTC
# 44  @Cicmty    CIC   Jun 22, 2024 · 4:34 PM UTC
# 45  @Cicmty    CIC   Jun 22, 2024 · 4:26 PM UTC
# 46  @Cicmty    CIC   Jun 22, 2024 · 4:23 PM UTC
# 47  @Cicmty    CIC   Jun 22, 2024 · 4:19 PM UTC
# 48  @Cicmty    CIC   Jun 22, 2024 · 4:16 PM UTC
# 49  @Cicmty    CIC   Jun 22, 2024 · 4:13 PM UTC
#
#                                                 Texto  Likes  Retweets  \
# 0                                                          7         0
# 1   💧#CuidadoDelAgua sin suministro en la Col. Bar...      1         0
# 2   💡#ServicioDeElectricidad sin servicio en Freno...      0         0
# 3   💡#ServicioDeElectricidad sin servicio en la Av...      1         0
# 4   💧#CuidadoDelAgua sin suministro en la Col. Mon...      1         0
# 5   💡#ServicioDeElectricidad sin servicio en Lomas...      2         0
# 6   💧#CuidadoDelAgua sin suministro en la Col. Ped...      0         0
# 7   💧#CuidadoDelAgua sin suministro en la Col. Tal...      0         0
# 8   💧#CuidadoDelAgua sin suministro en la Col. Mit...      1         0
# 9   💧#CuidadoDelAgua sin suministro en la Col. Lom...      0         0
# 10  💡#ServicioDeElectricidad sin servicio en Paseo...      2         1
# 11  💧#CuidadoDelAgua sin suministro en la Col. Los...      1         0
# 12  💧#CuidadoDelAgua sin suministro en la Col. Mit...      2         0
# 13  💧#CuidadoDelAgua sin suministro en la Col. Val...      2         0
# 14  🚦#SemáforoDescompuesto apagado en Av. Benito J...      3         0
# 15  💧#CuidadoDelAgua sin suministro en la Col. Uni...      1         0
# 16  💧#CuidadoDelAgua sin suministro en la Col. Val...      2         0
# 17  #Bache grande en Antiguo Camino a Apodaca y Av...      3         0
# 18  💧#CuidadoDelAgua sin suministro en la Col. Viñ...      0         0
# 19  💡#ServicioDeElectricidad bajo voltaje en Guyan...      2         0
# 20  💧#CuidadoDelAgua sin suministro en la Col. Vil...      1         0
# 21  💧#CuidadoDelAgua fuga de agua negras en A. Fid...      1         0
# 22  💡#ServicioDeElectricidad sin servicio en Av. D...      1         0
# 23  💧#CuidadoDelAgua sin suministro en la Col. Inf...      0         0
# 24  💡#ServicioDeElectricidad sin servicio en 13a A...      2         0
# 25  💧#CuidadoDelAgua sin suministro en la Col. Cum...      1         0
# 26  💧#CuidadoDelAgua sin suministro en la Col. Urb...      0         0
# 27  💧#CuidadoDelAgua sin suministro en la Col. Pro...      1         0
# 28  🚦#SemáforoDescompuesto apagado en Felipe de Je...      0         0
# 29  💧#CuidadoDelAgua sin suministro en la Col. Coo...      0         0
# 30  💧#CuidadoDelAgua sin suministro en la Col. Bos...      3         2
# 31  💧#CuidadoDelAgua sin suministro en la Col. Rev...      4         1
# 32  #RecolecciónDeBasura  solicitan desazolve en B...      1         0
# 33  💧#CuidadoDelAgua sin suministro en la Col. Pra...      0         0
# 34  #Ambiental árbol a punto de caer en  Carr. Nac...      5         0
# 35  💧#CuidadoDelAgua sin suministro en la Col. Lóp...      4         0
# 36  💧#CuidadoDelAgua sin suministro en la Col. Bri...      1         0
# 37  💧#CuidadoDelAgua sin suministro en la Col. Lom...      2         0
# 38  #CuidadoDelAgua sin suministro en la Col. Bosq...      4         1
# 39  💧#CuidadoDelAgua sin suministro en la Col. Col...      1         2
# 40  💧#CuidadoDelAgua sin suministro en la Col. San...      4         1
# 41  💧#CuidadoDelAgua sin suministro en la Col. Rea...      3         1
# 42  🚦#SemáforoDescompuesto apagado en Vicente Guer...      0         0
# 43  💧#CuidadoDelAgua sin suministro en la Col. Viñ...      1         0
# 44  💧#CuidadoDelAgua sin suministro en la Col. Cor...      4         1
# 45  💧#CuidadoDelAgua sin suministro en la Col. Res...      2         1
# 46  💧#CuidadoDelAgua sin suministro en la Col. San...      1         0
# 47  💧#CuidadoDelAgua sin suministro en la Col. Cum...      1         0
# 48  💧#CuidadoDelAgua sin suministro en la Col. Lom...      4         1
# 49  💧#CuidadoDelAgua sin suministro en la Col. Mis...      1         1
#
#     Comentarios  Citas                                             Enlace  \
# 0             0      0  https://twitter.com/Cicmty/status/180466833686...
# 1             5      0  https://twitter.com/Cicmty/status/180466642074...
# 2             0      0  https://twitter.com/Cicmty/status/180465759525...
# 3             0      0  https://twitter.com/Cicmty/status/180465562283...
# 4             2      0  https://twitter.com/Cicmty/status/180465453166...
# 5             0      0  https://twitter.com/Cicmty/status/180465073103...
# 6             0      0  https://twitter.com/Cicmty/status/180464908294...
# 7             0      0  https://twitter.com/Cicmty/status/180464851962...
# 8             0      1  https://twitter.com/Cicmty/status/180464731720...
# 9             1      0  https://twitter.com/Cicmty/status/180464681162...
# 10            0      1  https://twitter.com/Cicmty/status/180464262655...
# 11            1      0  https://twitter.com/Cicmty/status/180463908441...
# 12            0      0  https://twitter.com/Cicmty/status/180463255224...
# 13            0      0  https://twitter.com/Cicmty/status/180463194565...
# 14            0      0  https://twitter.com/Cicmty/status/180463135421...
# 15            3      0  https://twitter.com/Cicmty/status/180462179368...
# 16            2      0  https://twitter.com/Cicmty/status/180462128077...
# 17            0      0  https://twitter.com/Cicmty/status/180461947059...
# 18            1      0  https://twitter.com/Cicmty/status/180461570148...
# 19            0      0  https://twitter.com/Cicmty/status/180461131910...
# 20            2      0  https://twitter.com/Cicmty/status/180460916750...
# 21            1      0  https://twitter.com/Cicmty/status/180460854809...
# 22            0      0  https://twitter.com/Cicmty/status/180460690503...
# 23            1      0  https://twitter.com/Cicmty/status/180460014754...
# 24            0      0  https://twitter.com/Cicmty/status/180459772474...
# 25            1      0  https://twitter.com/Cicmty/status/180459605759...
# 26            1      0  https://twitter.com/Cicmty/status/180459516434...
# 27            1      0  https://twitter.com/Cicmty/status/180459305694...
# 28            0      1  https://twitter.com/Cicmty/status/180459089025...
# 29            0      0  https://twitter.com/Cicmty/status/180458979746...
# 30            2      0  https://twitter.com/Cicmty/status/180458210338...
# 31            0      0  https://twitter.com/Cicmty/status/180458136839...
# 32            0      1  https://twitter.com/Cicmty/status/180457979919...
# 33            0      0  https://twitter.com/Cicmty/status/180457512213...
# 34            0      0  https://twitter.com/Cicmty/status/180457438237...
# 35            2      0  https://twitter.com/Cicmty/status/180456689637...
# 36            1      0  https://twitter.com/Cicmty/status/180456459482...
# 37            1      0  https://twitter.com/Cicmty/status/180456408807...
# 38            0      0  https://twitter.com/Cicmty/status/180456219856...
# 39            0      0  https://twitter.com/Cicmty/status/180456155549...
# 40            1      0  https://twitter.com/Cicmty/status/180456012944...
# 41            1      0  https://twitter.com/Cicmty/status/180455781076...
# 42            0      0  https://twitter.com/Cicmty/status/180455674168...
# 43            0      0  https://twitter.com/Cicmty/status/180455529202...
# 44            0      0  https://twitter.com/Cicmty/status/180455362268...
# 45            0      0  https://twitter.com/Cicmty/status/180455162527...
# 46            1      0  https://twitter.com/Cicmty/status/180455088777...
# 47            0      1  https://twitter.com/Cicmty/status/180454968207...
# 48            0      0  https://twitter.com/Cicmty/status/180454897278...
# 49            0      0  https://twitter.com/Cicmty/status/180454836867...
#
#                                              Imágenes
# 0   [https://pbs.twimg.com/media/GQt4QsNWUAAdaBc.jpg]
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17  [https://pbs.twimg.com/media/GQtLY-7bQAAQ-Vv.jpg]
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  [https://pbs.twimg.com/media/GQtBswiawAAiPUr.jpg]
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  [https://pbs.twimg.com/media/GQsmon_agAAcRJy.jpg]
# 33                                                NaN
# 34  [https://pbs.twimg.com/media/GQshT4fbUAA32EO.jpg]
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
